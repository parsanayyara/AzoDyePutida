# %% [markdown]
# #### Pathway Utilization Analysis
#
# - Model: iJN1462c

# %%
# import packages
import cobra.test
import os
from os.path import join

data_dir = cobra.test.data_dir

from __future__ import print_function

from cobra import Model, Reaction, Metabolite

# %%
# read model
model = cobra.io.read_sbml_model(join(data_dir, modelfilepath))
model.solver = "cplex"

# %%
# change default medium bounds to match M9 in silico minimal media composition 
# as described in Nogales et al. 2020

cobra.Reaction("EX_ca2_e", lower_bound = -10, upper_bound = 1000.0)
cobra.Reaction("EX_co2_e", lower_bound = -100, upper_bound = 1000.0)
cobra.Reaction("EX_cobalt2_e", lower_bound = -10, upper_bound = 1000.0)
cobra.Reaction("EX_cu2_e", lower_bound = -10, upper_bound = 1000.0)
cobra.Reaction("EX_cl_e", lower_bound = -10, upper_bound = 1000.0)
cobra.Reaction("EX_fe2_e", lower_bound = -10, upper_bound = 1000.0)
cobra.Reaction("EX_glc__D_e", lower_bound = -6.3, upper_bound = 1000.0)
cobra.Reaction("EX_h2o_e", lower_bound = -100, upper_bound = 1000.0)
cobra.Reaction("EX_h_e", lower_bound = -100, upper_bound = 1000.0)
cobra.Reaction("EX_hco3_e", lower_bound = -10, upper_bound = 1000.0)
cobra.Reaction("EX_k_e", lower_bound = -10, upper_bound = 1000.0)
cobra.Reaction("EX_mg2_e", lower_bound = -10, upper_bound = 1000.0)
cobra.Reaction("EX_mn2_e", lower_bound = -10, upper_bound = 1000.0)
cobra.Reaction("EX_mobd_e", lower_bound = -10, upper_bound = 1000.0)
cobra.Reaction("EX_nh4_e", lower_bound = -10, upper_bound = 1000.0)
cobra.Reaction("EX_ni2_e", lower_bound = -10, upper_bound = 1000.0)
cobra.Reaction("EX_o2_e", lower_bound = -30, upper_bound = 1000.0)
cobra.Reaction("EX_pi_e", lower_bound = -10, upper_bound = 1000.0)
cobra.Reaction("EX_sel_e", lower_bound = -10, upper_bound = 1000.0)
cobra.Reaction("EX_so4_e", lower_bound = -10, upper_bound = 1000.0)
cobra.Reaction("EX_tungs_e", lower_bound = -10, upper_bound = 1000.0)
cobra.Reaction("EX_zn2_e", lower_bound = -10, upper_bound = 1000.0)
cobra.Reaction("EX_MR", lower_bound = -1000, upper_bound = 1000.0)


medium = model.medium
medium["EX_acmtsoxin_e"] = 0.0
medium["EX_acpptrn_e"] = 0.0
medium["EX_d2one_e"] = 0.0
medium["EX_d3one_e"] = 0.0
medium["EX_d4one_e"] = 0.0
medium["EX_mtsoxin_e"] = 0.0
medium["EX_n2one_e"] = 0.0
medium["EX_pptrn_e"] = 0.0
medium["EX_und2one_e"] = 0.0
medium["EX_gACT[e]"] = 0.0
medium["EX_nh4_e"] = 10.0
medium["EX_o2_e"] = 30.0

### change carbon sources ###

medium["EX_MR"] = 0.0
medium["EX_glc__D_e"] = 6.3

model.medium = medium

model.medium
# Out:
# {'EX_ca2_e': 10.0,
#  'EX_cl_e': 10.0,
#  'EX_co2_e': 100.0,
#  'EX_cobalt2_e': 10.0,
#  'EX_cu2_e': 10.0,
#  'EX_fe2_e': 10.0,
#  'EX_glc__D_e': 6.3,
#  'EX_h2o_e': 100.0,
#  'EX_h_e': 100.0,
#  'EX_hco3_e': 10.0,
#  'EX_k_e': 10.0,
#  'EX_mg2_e': 10.0,
#  'EX_mn2_e': 10.0,
#  'EX_mobd_e': 10.0,
#  'EX_na1_e': 10.0,
#  'EX_nh4_e': 10.0,
#  'EX_ni2_e': 10.0,
#  'EX_o2_e': 30.0,
#  'EX_pi_e': 10.0,
#  'EX_sel_e': 10.0,
#  'EX_so4_e': 10.0,
#  'EX_tungs_e': 10.0,
#  'EX_zn2_e': 10.0}

# %%
### set model objective to growth / ACTt ###

model.objective = "BIOMASS_KT2440_WT3"

# %%
# retrieve fluxes from producing and consuming reactions for the given metabolite

model.metabolites.accoa_c.summary()
# Out:
# <h3>accoa_c</h3><p>C23H34N7O17P3S</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5.91%</td>
#       <td>0.362</td>
#       <td>ACS</td>
#       <td>ac_c + atp_c + coa_c --&gt; accoa_c + amp_c + ppi_c</td>
#     </tr>
#     <tr>
#       <td>94.09%</td>
#       <td>5.762</td>
#       <td>PDH</td>
#       <td>coa_c + nad_c + pyr_c --&gt; accoa_c + co2_c + nadh_c</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5.04%</td>
#       <td>-0.3085</td>
#       <td>ACALD</td>
#       <td>acald_c + coa_c + nad_c &lt;=&gt; accoa_c + h_c + nadh_c</td>
#     </tr>
#     <tr>
#       <td>19.44%</td>
#       <td>-1.191</td>
#       <td>ACCOAC</td>
#       <td>accoa_c + atp_c + hco3_c --&gt; adp_c + h_c + malcoa_c + pi_c</td>
#     </tr>
#     <tr>
#       <td>3.90%</td>
#       <td>-0.2388</td>
#       <td>ACGS</td>
#       <td>accoa_c + glu__L_c --&gt; acglu_c + coa_c + h_c</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>-0.0001718</td>
#       <td>BIOMASS_KT2440_WT3</td>
#       <td>0.000223 10fthf_c + 0.000223 2fe2s_c + 0.000223 4fe4s_c + 0.000223 5mthf_c + 0.000279 accoa_c + 0.000223 adocbl_c + 0.598267 ala__L_c + 0.000223 amet_c + 0.354251 arg__L_c + 0.158931 asn__L_c + 0.284685 asp__L_c + 46.918883 atp_c + 0.000223 bmocogdp_c + 0.000223 btamp_c + 0.004226 ca2_c + 0.000223 chor_c + 0.004226 cl_c + 1.8e-05 clpn140_p + 0.000578 clpn160_p + 0.002873 clpn161_p + 0.000192 clpn180_p + 0.001309 clpn181_p + 0.000167 coa_c + 0.002817 cobalt2_c + 0.00041 cpe160_c + 0.000226 cpg160_c + 0.159783 ctp_c + 0.002817 cu2_c + 0.055652 cys__L_c + 0.010804 datp_c + 0.01721 dctp_c + 0.017423 dgtp_c + 0.010854 dttp_c + 0.000223 fad_c + 0.00634 fe2_c + 0.00634 fe3_c + 0.251507 gln__L_c + 0.301809 glu__L_c + 0.431309 gly_c + 0.000223 gthrd_c + 0.210704 gtp_c + 41.397362 h2o_c + 0.000223 hemeO_c + 0.126289 his__L_c + 0.244551 ile__L_c + 0.158509 k_c + 0.628769 leu__L_c + 0.000223 lipopb_c + 0.008696 lpspput_e + 0.180336 lys__L_c + 3.1e-05 malcoa_c + 0.122008 met__L_c + 0.007044 mg2_c + 0.000223 mlthf_c + 0.002817 mn2_c + 0.002817 mobd_c + 0.000223 mocogdp_c + 0.001979 murein3p3p_p + 0.000326 murein3px4p_p + 0.007917 murein4p4p_p + 0.002941 murein4px4p_p + 6.6e-05 murein4px4px4p_p + 0.003522 na1_c + 0.001786 nad_c + 4.4e-05 nadh_c + 0.000111 nadp_c + 0.000335 nadph_c + 0.010567 nh4_c + 0.002817 ni2_c + 0.000251 pe140_c + 0.007882 pe160_c + 0.039155 pe161_c + 0.002622 pe180_c + 0.017845 pe181_c + 0.000138 pg140_c + 0.004354 pg160_c + 0.021632 pg161_c + 0.001449 pg180_c + 0.009859 pg181_c + 0.191038 phe__L_c + 0.000223 pheme_c + 0.000223 pqqh2_c + 0.26328 pro__L_c + 0.03327 ptrc_c + 0.000223 pydx5p_c + 0.000223 pyovd_kt_e + 0.000223 q8h2_c + 0.000223 ribflv_c + 0.301274 ser__L_c + 0.000223 sheme_c + 0.003522 so4_c + 9.8e-05 succoa_c + 0.000223 thf_c + 0.000223 thmnp_c + 0.000223 thmpp_c + 0.256324 thr__L_c + 0.077592 trp__L_c + 0.135921 tyr__L_c + 5.5e-05 udcpdp_c + 0.143215 utp_c + 0.389034 val__L_c + 0.002817 zn2_c --&gt; 46.7502 adp_c + 46.7502 h_c + 46.746677 pi_c + 0.73868 ppi_c</td>
#     </tr>
#     <tr>
#       <td>59.80%</td>
#       <td>-3.662</td>
#       <td>CS</td>
#       <td>accoa_c + h2o_c + oaa_c --&gt; cit_c + coa_c + h_c</td>
#     </tr>
#     <tr>
#       <td>0.80%</td>
#       <td>-0.04872</td>
#       <td>G1PACT</td>
#       <td>accoa_c + gam1p_c --&gt; acgam1p_c + coa_c + h_c</td>
#     </tr>
#     <tr>
#       <td>1.23%</td>
#       <td>-0.07539</td>
#       <td>HSERTA</td>
#       <td>accoa_c + hom__L_c &lt;=&gt; achms_c + coa_c</td>
#     </tr>
#     <tr>
#       <td>6.32%</td>
#       <td>-0.3871</td>
#       <td>IPPS</td>
#       <td>3mob_c + accoa_c + h2o_c --&gt; 3c3hmp_c + coa_c + h_c</td>
#     </tr>
#     <tr>
#       <td>2.85%</td>
#       <td>-0.1748</td>
#       <td>KAS15</td>
#       <td>accoa_c + h_c + malACP_c --&gt; actACP_c + co2_c + coa_c</td>
#     </tr>
#     <tr>
#       <td>0.01%</td>
#       <td>-0.0005491</td>
#       <td>MALS</td>
#       <td>accoa_c + glx_c + h2o_c --&gt; coa_c + h_c + mal__L_c</td>
#     </tr>
#     <tr>
#       <td>0.60%</td>
#       <td>-0.03695</td>
#       <td>SERAT_copy1</td>
#       <td>accoa_c + ser__L_c &lt;=&gt; acser_c + coa_c</td>
#     </tr>
#   </tbody>
# </table>

# %%
# retrieve fluxes from producing and consuming reactions for the given metabolite

model.metabolites.akg_c.summary()
# Out:
# <h3>akg_c</h3><p>C5H4O5</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>3.32%</td>
#       <td>0.2388</td>
#       <td>ACOTA</td>
#       <td>acorn_c + akg_c &lt;=&gt; acg5sa_c + glu__L_c</td>
#     </tr>
#     <tr>
#       <td>5.58%</td>
#       <td>0.4016</td>
#       <td>ALATA_L</td>
#       <td>akg_c + ala__L_c &lt;=&gt; glu__L_c + pyr_c</td>
#     </tr>
#     <tr>
#       <td>1.63%</td>
#       <td>0.1176</td>
#       <td>AROAT</td>
#       <td>glu__L_c + h_c + pphn_c &lt;=&gt; Largn_c + akg_c</td>
#     </tr>
#     <tr>
#       <td>18.69%</td>
#       <td>1.346</td>
#       <td>ASPTA</td>
#       <td>akg_c + asp__L_c &lt;=&gt; glu__L_c + oaa_c</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>0.0001373</td>
#       <td>DABAAT2</td>
#       <td>24dab_c + akg_c + h_c &lt;=&gt; aspsa_c + glu__L_c</td>
#     </tr>
#     <tr>
#       <td>1.08%</td>
#       <td>0.07775</td>
#       <td>HSTPT</td>
#       <td>glu__L_c + imacp_c --&gt; akg_c + hisp_c</td>
#     </tr>
#     <tr>
#       <td>50.85%</td>
#       <td>3.662</td>
#       <td>ICDHyr</td>
#       <td>icit_c + nadp_c &lt;=&gt; akg_c + co2_c + nadph_c</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>0.0001373</td>
#       <td>OHPBAT</td>
#       <td>glu__L_c + ohpb_c &lt;=&gt; akg_c + phthr_c</td>
#     </tr>
#     <tr>
#       <td>15.93%</td>
#       <td>1.147</td>
#       <td>PSERT</td>
#       <td>3php_c + glu__L_c --&gt; akg_c + pser__L_c</td>
#     </tr>
#     <tr>
#       <td>1.77%</td>
#       <td>0.1273</td>
#       <td>SDPTA</td>
#       <td>akg_c + sl26da_c &lt;=&gt; glu__L_c + sl2a6o_c</td>
#     </tr>
#     <tr>
#       <td>1.16%</td>
#       <td>0.08381</td>
#       <td>TYRTA</td>
#       <td>akg_c + tyr__L_c &lt;=&gt; 34hpp_c + glu__L_c</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>40.10%</td>
#       <td>-2.889</td>
#       <td>AKGDH</td>
#       <td>akg_c + coa_c + nad_c --&gt; co2_c + nadh_c + succoa_c</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>-0.0001373</td>
#       <td>ASP3H</td>
#       <td>akg_c + asp__L_c + o2_c --&gt; 3hasp__L_c + co2_c + succ_c</td>
#     </tr>
#     <tr>
#       <td>53.92%</td>
#       <td>-3.884</td>
#       <td>GLUDxi</td>
#       <td>glu__L_c + h2o_c + nad_c &lt;=&gt; akg_c + h_c + nadh_c + nh4_c</td>
#     </tr>
#     <tr>
#       <td>5.83%</td>
#       <td>-0.4198</td>
#       <td>GLUDy</td>
#       <td>glu__L_c + h2o_c + nadp_c &lt;=&gt; akg_c + h_c + nadph_c + nh4_c</td>
#     </tr>
#     <tr>
#       <td>0.15%</td>
#       <td>-0.01071</td>
#       <td>LIPAH</td>
#       <td>2.0 akg_c + lipa_kt_c + 2.0 o2_c --&gt; 2.0 co2_c + lipa_oh_c + 2.0 succ_c</td>
#     </tr>
#   </tbody>
# </table>

# %%
# retrieve fluxes from producing and consuming reactions for the given metabolite

model.metabolites.glx_c.summary()
# Out:
# <h3>glx_c</h3><p>C2H1O3</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100.00%</td>
#       <td>0.0005491</td>
#       <td>GLYCTO1</td>
#       <td>glyclt_c + o2_c --&gt; glx_c + h2o2_c</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100.00%</td>
#       <td>-0.0005491</td>
#       <td>MALS</td>
#       <td>accoa_c + glx_c + h2o_c --&gt; coa_c + h_c + mal__L_c</td>
#     </tr>
#   </tbody>
# </table>

# %%
# retrieve fluxes from producing and consuming reactions for the given metabolite

model.metabolites.pep_c.summary()
# Out:
# <h3>pep_c</h3><p>C3H2O6P</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100.00%</td>
#       <td>4.17</td>
#       <td>ENO</td>
#       <td>2pg_c &lt;=&gt; h2o_c + pep_c</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.26%</td>
#       <td>-0.01073</td>
#       <td>AGPOP</td>
#       <td>dgdp_c + h_c + pep_c --&gt; dgtp_c + pyr_c</td>
#     </tr>
#     <tr>
#       <td>5.99%</td>
#       <td>-0.2499</td>
#       <td>DDPA</td>
#       <td>e4p_c + h2o_c + pep_c --&gt; 2dda7p_c + pi_c</td>
#     </tr>
#     <tr>
#       <td>0.26%</td>
#       <td>-0.01071</td>
#       <td>KDOPS</td>
#       <td>ara5p_c + h2o_c + pep_c --&gt; kdo8p_c + pi_c</td>
#     </tr>
#     <tr>
#       <td>34.63%</td>
#       <td>-1.444</td>
#       <td>PPC</td>
#       <td>co2_c + h2o_c + pep_c --&gt; h_c + oaa_c + pi_c</td>
#     </tr>
#     <tr>
#       <td>5.99%</td>
#       <td>-0.2499</td>
#       <td>PSCVT_copy2</td>
#       <td>pep_c + skm5p_c --&gt; 3psme_c + pi_c</td>
#     </tr>
#     <tr>
#       <td>52.48%</td>
#       <td>-2.189</td>
#       <td>PYK</td>
#       <td>adp_c + h_c + pep_c --&gt; atp_c + pyr_c</td>
#     </tr>
#     <tr>
#       <td>0.39%</td>
#       <td>-0.01633</td>
#       <td>UAGCVT</td>
#       <td>pep_c + uacgam_c --&gt; pi_c + uaccg_c</td>
#     </tr>
#   </tbody>
# </table>

# %%
# retrieve fluxes from producing and consuming reactions for the given metabolite

model.metabolites.pyr_c.summary()
# Out:
# <h3>pyr_c</h3><p>C3H3O3</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.01%</td>
#       <td>0.0005491</td>
#       <td>ADCL</td>
#       <td>4adcho_c --&gt; 4abz_c + h_c + pyr_c</td>
#     </tr>
#     <tr>
#       <td>0.14%</td>
#       <td>0.01073</td>
#       <td>AGPOP</td>
#       <td>dgdp_c + h_c + pep_c --&gt; dgtp_c + pyr_c</td>
#     </tr>
#     <tr>
#       <td>0.62%</td>
#       <td>0.04777</td>
#       <td>ANS2</td>
#       <td>chor_c + nh4_c --&gt; anth_c + h2o_c + h_c + pyr_c</td>
#     </tr>
#     <tr>
#       <td>70.80%</td>
#       <td>5.45</td>
#       <td>EDA</td>
#       <td>2ddg6p_c --&gt; g3p_c + pyr_c</td>
#     </tr>
#     <tr>
#       <td>28.43%</td>
#       <td>2.189</td>
#       <td>PYK</td>
#       <td>adp_c + h_c + pep_c --&gt; atp_c + pyr_c</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1.96%</td>
#       <td>-0.1506</td>
#       <td>ACHBS</td>
#       <td>2obut_c + h_c + pyr_c --&gt; 2ahbut_c + co2_c</td>
#     </tr>
#     <tr>
#       <td>16.29%</td>
#       <td>-1.254</td>
#       <td>ACLS</td>
#       <td>h_c + 2.0 pyr_c --&gt; alac__S_c + co2_c</td>
#     </tr>
#     <tr>
#       <td>5.22%</td>
#       <td>-0.4016</td>
#       <td>ALATA_L</td>
#       <td>akg_c + ala__L_c &lt;=&gt; glu__L_c + pyr_c</td>
#     </tr>
#     <tr>
#       <td>1.65%</td>
#       <td>-0.1273</td>
#       <td>DHDPS</td>
#       <td>aspsa_c + pyr_c --&gt; 23dhdp_c + 2.0 h2o_c + h_c</td>
#     </tr>
#     <tr>
#       <td>0.03%</td>
#       <td>-0.002157</td>
#       <td>DXPS</td>
#       <td>g3p_c + h_c + pyr_c --&gt; co2_c + dxyl5p_c</td>
#     </tr>
#     <tr>
#       <td>74.86%</td>
#       <td>-5.762</td>
#       <td>PDH</td>
#       <td>coa_c + nad_c + pyr_c --&gt; accoa_c + co2_c + nadh_c</td>
#     </tr>
#   </tbody>
# </table>

# %%
# retrieve fluxes from producing and consuming reactions for the given metabolite

model.metabolites.ru5p__D_c.summary()
# Out:
# <h3>ru5p__D_c</h3><p>C5H9O8P</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100.00%</td>
#       <td>0.8498</td>
#       <td>GND</td>
#       <td>6pgc_c + nadp_c --&gt; co2_c + nadph_c + ru5p__D_c</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1.26%</td>
#       <td>-0.01071</td>
#       <td>A5PISO</td>
#       <td>ru5p__D_c &lt;=&gt; ara5p_c</td>
#     </tr>
#     <tr>
#       <td>0.10%</td>
#       <td>-0.0008237</td>
#       <td>DB4PS</td>
#       <td>ru5p__D_c --&gt; db4p_c + for_c + h_c</td>
#     </tr>
#     <tr>
#       <td>9.51%</td>
#       <td>-0.08084</td>
#       <td>RPE</td>
#       <td>ru5p__D_c &lt;=&gt; xu5p__D_c</td>
#     </tr>
#     <tr>
#       <td>89.13%</td>
#       <td>-0.7574</td>
#       <td>RPI</td>
#       <td>r5p_c &lt;=&gt; ru5p__D_c</td>
#     </tr>
#   </tbody>
# </table>

# %%
# retrieve fluxes from producing and consuming reactions for the given metabolite

model.metabolites.xu5p__D_c.summary()
# Out:
# <h3>xu5p__D_c</h3><p>C5H9O8P</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>47.35%</td>
#       <td>0.08084</td>
#       <td>RPE</td>
#       <td>ru5p__D_c &lt;=&gt; xu5p__D_c</td>
#     </tr>
#     <tr>
#       <td>52.65%</td>
#       <td>0.08987</td>
#       <td>TKT2</td>
#       <td>e4p_c + xu5p__D_c &lt;=&gt; f6p_c + g3p_c</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100.00%</td>
#       <td>-0.1707</td>
#       <td>TKT1</td>
#       <td>r5p_c + xu5p__D_c &lt;=&gt; g3p_c + s7p_c</td>
#     </tr>
#   </tbody>
# </table>

# %%
# retrieve fluxes from producing and consuming reactions for the given metabolite

model.metabolites.dhap_c.summary()
# Out:
# <h3>dhap_c</h3><p>C3H5O6P</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100.00%</td>
#       <td>0.09891</td>
#       <td>TPI</td>
#       <td>dhap_c &lt;=&gt; g3p_c</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>98.58%</td>
#       <td>-0.09751</td>
#       <td>G3PD2</td>
#       <td>glyc3p_c + nadp_c &lt;=&gt; dhap_c + h_c + nadph_c</td>
#     </tr>
#     <tr>
#       <td>1.42%</td>
#       <td>-0.001401</td>
#       <td>QULNS</td>
#       <td>dhap_c + iasp_c --&gt; 2.0 h2o_c + pi_c + quln_c</td>
#     </tr>
#   </tbody>
# </table>

# %%
# retrieve fluxes from producing and consuming reactions for the given metabolite

model.metabolites.g6p_c.summary()
# Out:
# <h3>g6p_c</h3><p>C6H11O9P</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100.00%</td>
#       <td>0.02141</td>
#       <td>PGI</td>
#       <td>g6p_c &lt;=&gt; f6p_c</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100.00%</td>
#       <td>-0.02141</td>
#       <td>PGMT</td>
#       <td>g1p_c &lt;=&gt; g6p_c</td>
#     </tr>
#   </tbody>
# </table>

# %%
# retrieve fluxes from producing and consuming reactions for the given metabolite

model.metabolites.g3p_c.summary()
# Out:
# <h3>g3p_c</h3><p>C3H5O6P</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>96.15%</td>
#       <td>5.45</td>
#       <td>EDA</td>
#       <td>2ddg6p_c --&gt; g3p_c + pyr_c</td>
#     </tr>
#     <tr>
#       <td>3.01%</td>
#       <td>0.1707</td>
#       <td>TKT1</td>
#       <td>r5p_c + xu5p__D_c &lt;=&gt; g3p_c + s7p_c</td>
#     </tr>
#     <tr>
#       <td>0.84%</td>
#       <td>0.04777</td>
#       <td>TRPS1_copy2</td>
#       <td>3ig3p_c + ser__L_c --&gt; g3p_c + h2o_c + trp__L_c</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.04%</td>
#       <td>-0.002157</td>
#       <td>DXPS</td>
#       <td>g3p_c + h_c + pyr_c --&gt; co2_c + dxyl5p_c</td>
#     </tr>
#     <tr>
#       <td>25.30%</td>
#       <td>-1.434</td>
#       <td>GAPD</td>
#       <td>g3p_c + nad_c + pi_c &lt;=&gt; 13dpg_c + h_c + nadh_c</td>
#     </tr>
#     <tr>
#       <td>68.51%</td>
#       <td>-3.884</td>
#       <td>GAPDi_nadp</td>
#       <td>13dpg_c + h_c + nadph_c &lt;=&gt; g3p_c + nadp_c + pi_c</td>
#     </tr>
#     <tr>
#       <td>2.82%</td>
#       <td>-0.16</td>
#       <td>TALA</td>
#       <td>g3p_c + s7p_c &lt;=&gt; e4p_c + f6p_c</td>
#     </tr>
#     <tr>
#       <td>1.59%</td>
#       <td>-0.08987</td>
#       <td>TKT2</td>
#       <td>e4p_c + xu5p__D_c &lt;=&gt; f6p_c + g3p_c</td>
#     </tr>
#     <tr>
#       <td>1.74%</td>
#       <td>-0.09891</td>
#       <td>TPI</td>
#       <td>dhap_c &lt;=&gt; g3p_c</td>
#     </tr>
#   </tbody>
# </table>

# %%
# retrieve fluxes from producing and consuming reactions for the given metabolite

model.metabolites.glyc_c.summary()
# Out:
# <h3>glyc_c</h3><p>C3H8O3</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100.00%</td>
#       <td>0.00306</td>
#       <td>GLYCtpp</td>
#       <td>glyc_c &lt;=&gt; glyc_p</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100.00%</td>
#       <td>-0.00306</td>
#       <td>GLYK</td>
#       <td>atp_c + glyc_c --&gt; adp_c + glyc3p_c + h_c</td>
#     </tr>
#   </tbody>
# </table>

# %%
# retrieve fluxes from producing and consuming reactions for the given metabolite

model.metabolites.fum_c.summary()
# Out:
# <h3>fum_c</h3><p>C4H2O4</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5.35%</td>
#       <td>0.1907</td>
#       <td>ADSL1r</td>
#       <td>dcamp_c &lt;=&gt; amp_c + fum_c</td>
#     </tr>
#     <tr>
#       <td>7.16%</td>
#       <td>0.2553</td>
#       <td>ADSL2r</td>
#       <td>25aics_c &lt;=&gt; aicar_c + fum_c</td>
#     </tr>
#     <tr>
#       <td>6.12%</td>
#       <td>0.2181</td>
#       <td>ARGSL</td>
#       <td>argsuc_c &lt;=&gt; arg__L_c + fum_c</td>
#     </tr>
#     <tr>
#       <td>81.36%</td>
#       <td>2.899</td>
#       <td>SUCDi</td>
#       <td>q8_c + succ_c --&gt; fum_c + q8h2_c</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100.00%</td>
#       <td>-3.563</td>
#       <td>FUM</td>
#       <td>fum_c + h2o_c &lt;=&gt; mal__L_c</td>
#     </tr>
#   </tbody>
# </table>

# %%
# retrieve fluxes from producing and consuming reactions for the given metabolite

model.metabolites.cit_c.summary()
# Out:
# <h3>cit_c</h3><p>C6H5O7</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>99.72%</td>
#       <td>3.662</td>
#       <td>CS</td>
#       <td>accoa_c + h2o_c + oaa_c --&gt; cit_c + coa_c + h_c</td>
#     </tr>
#     <tr>
#       <td>0.28%</td>
#       <td>0.01028</td>
#       <td>FE3DCITR</td>
#       <td>fdxr_42_c + 2.0 fe3dcit_c --&gt; 4.0 cit_c + fdxo_42_c + 2.0 fe2_c</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>99.72%</td>
#       <td>-3.662</td>
#       <td>ACONTa</td>
#       <td>cit_c &lt;=&gt; acon_C_c + h2o_c</td>
#     </tr>
#     <tr>
#       <td>0.28%</td>
#       <td>-0.01028</td>
#       <td>FE3DCITCH</td>
#       <td>2.0 cit_c + fe3_c &lt;=&gt; fe3dcit_c</td>
#     </tr>
#   </tbody>
# </table>

# %%
# retrieve fluxes from producing and consuming reactions for the given metabolite

model.metabolites.oaa_c.summary()
# Out:
# <h3>oaa_c</h3><p>C4H2O5</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>71.16%</td>
#       <td>3.564</td>
#       <td>MDH</td>
#       <td>mal__L_c + nad_c &lt;=&gt; h_c + nadh_c + oaa_c</td>
#     </tr>
#     <tr>
#       <td>28.84%</td>
#       <td>1.444</td>
#       <td>PPC</td>
#       <td>co2_c + h2o_c + pep_c --&gt; h_c + oaa_c + pi_c</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>26.87%</td>
#       <td>-1.346</td>
#       <td>ASPTA</td>
#       <td>akg_c + asp__L_c &lt;=&gt; glu__L_c + oaa_c</td>
#     </tr>
#     <tr>
#       <td>73.13%</td>
#       <td>-3.662</td>
#       <td>CS</td>
#       <td>accoa_c + h2o_c + oaa_c --&gt; cit_c + coa_c + h_c</td>
#     </tr>
#   </tbody>
# </table>

# %%
# retrieve fluxes from producing and consuming reactions for the given metabolite

model.metabolites.ser__L_c.summary()
# Out:
# <h3>ser__L_c</h3><p>C3H7NO3</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100.00%</td>
#       <td>1.147</td>
#       <td>PSP_L</td>
#       <td>h2o_c + pser__L_c --&gt; pi_c + ser__L_c</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>16.16%</td>
#       <td>-0.1855</td>
#       <td>BIOMASS_KT2440_WT3</td>
#       <td>0.000223 10fthf_c + 0.000223 2fe2s_c + 0.000223 4fe4s_c + 0.000223 5mthf_c + 0.000279 accoa_c + 0.000223 adocbl_c + 0.598267 ala__L_c + 0.000223 amet_c + 0.354251 arg__L_c + 0.158931 asn__L_c + 0.284685 asp__L_c + 46.918883 atp_c + 0.000223 bmocogdp_c + 0.000223 btamp_c + 0.004226 ca2_c + 0.000223 chor_c + 0.004226 cl_c + 1.8e-05 clpn140_p + 0.000578 clpn160_p + 0.002873 clpn161_p + 0.000192 clpn180_p + 0.001309 clpn181_p + 0.000167 coa_c + 0.002817 cobalt2_c + 0.00041 cpe160_c + 0.000226 cpg160_c + 0.159783 ctp_c + 0.002817 cu2_c + 0.055652 cys__L_c + 0.010804 datp_c + 0.01721 dctp_c + 0.017423 dgtp_c + 0.010854 dttp_c + 0.000223 fad_c + 0.00634 fe2_c + 0.00634 fe3_c + 0.251507 gln__L_c + 0.301809 glu__L_c + 0.431309 gly_c + 0.000223 gthrd_c + 0.210704 gtp_c + 41.397362 h2o_c + 0.000223 hemeO_c + 0.126289 his__L_c + 0.244551 ile__L_c + 0.158509 k_c + 0.628769 leu__L_c + 0.000223 lipopb_c + 0.008696 lpspput_e + 0.180336 lys__L_c + 3.1e-05 malcoa_c + 0.122008 met__L_c + 0.007044 mg2_c + 0.000223 mlthf_c + 0.002817 mn2_c + 0.002817 mobd_c + 0.000223 mocogdp_c + 0.001979 murein3p3p_p + 0.000326 murein3px4p_p + 0.007917 murein4p4p_p + 0.002941 murein4px4p_p + 6.6e-05 murein4px4px4p_p + 0.003522 na1_c + 0.001786 nad_c + 4.4e-05 nadh_c + 0.000111 nadp_c + 0.000335 nadph_c + 0.010567 nh4_c + 0.002817 ni2_c + 0.000251 pe140_c + 0.007882 pe160_c + 0.039155 pe161_c + 0.002622 pe180_c + 0.017845 pe181_c + 0.000138 pg140_c + 0.004354 pg160_c + 0.021632 pg161_c + 0.001449 pg180_c + 0.009859 pg181_c + 0.191038 phe__L_c + 0.000223 pheme_c + 0.000223 pqqh2_c + 0.26328 pro__L_c + 0.03327 ptrc_c + 0.000223 pydx5p_c + 0.000223 pyovd_kt_e + 0.000223 q8h2_c + 0.000223 ribflv_c + 0.301274 ser__L_c + 0.000223 sheme_c + 0.003522 so4_c + 9.8e-05 succoa_c + 0.000223 thf_c + 0.000223 thmnp_c + 0.000223 thmpp_c + 0.256324 thr__L_c + 0.077592 trp__L_c + 0.135921 tyr__L_c + 5.5e-05 udcpdp_c + 0.143215 utp_c + 0.389034 val__L_c + 0.002817 zn2_c --&gt; 46.7502 adp_c + 46.7502 h_c + 46.746677 pi_c + 0.73868 ppi_c</td>
#     </tr>
#     <tr>
#       <td>0.01%</td>
#       <td>-0.0001373</td>
#       <td>FBACS</td>
#       <td>24dab_c + 3hasp__L_c + asp__L_c + gly_c + n5horn_c + orn_c + ser__L_c --&gt; fbac_kt_c + 6.0 h2o_c</td>
#     </tr>
#     <tr>
#       <td>58.75%</td>
#       <td>-0.674</td>
#       <td>GHMT2r</td>
#       <td>ser__L_c + thf_c --&gt; gly_c + h2o_c + mlthf_c</td>
#     </tr>
#     <tr>
#       <td>13.57%</td>
#       <td>-0.1557</td>
#       <td>LSERDHr</td>
#       <td>nadp_c + ser__L_c &lt;=&gt; 2amsa_c + h_c + nadph_c</td>
#     </tr>
#     <tr>
#       <td>0.01%</td>
#       <td>-0.0001545</td>
#       <td>PSSA140</td>
#       <td>cdpdtdecg_c + ser__L_c --&gt; cmp_c + h_c + ps140_c</td>
#     </tr>
#     <tr>
#       <td>0.42%</td>
#       <td>-0.004852</td>
#       <td>PSSA160</td>
#       <td>cdpdhdecg_c + ser__L_c --&gt; cmp_c + h_c + ps160_c</td>
#     </tr>
#     <tr>
#       <td>2.12%</td>
#       <td>-0.02436</td>
#       <td>PSSA161</td>
#       <td>cdpdhdec9eg_c + ser__L_c --&gt; cmp_c + h_c + ps161_c</td>
#     </tr>
#     <tr>
#       <td>0.14%</td>
#       <td>-0.001614</td>
#       <td>PSSA180</td>
#       <td>cdpdodecg_c + ser__L_c --&gt; cmp_c + h_c + ps180_c</td>
#     </tr>
#     <tr>
#       <td>1.42%</td>
#       <td>-0.01634</td>
#       <td>PSSA181</td>
#       <td>cdpdodec11eg_c + ser__L_c --&gt; cmp_c + h_c + ps181_c</td>
#     </tr>
#     <tr>
#       <td>3.22%</td>
#       <td>-0.03695</td>
#       <td>SERAT_copy1</td>
#       <td>accoa_c + ser__L_c &lt;=&gt; acser_c + coa_c</td>
#     </tr>
#     <tr>
#       <td>4.16%</td>
#       <td>-0.04777</td>
#       <td>TRPS1_copy2</td>
#       <td>3ig3p_c + ser__L_c --&gt; g3p_c + h2o_c + trp__L_c</td>
#     </tr>
#   </tbody>
# </table>

# %%
# retrieve fluxes from producing and consuming reactions for the given metabolite

model.metabolites.glu__L_c.summary()
# Out:
# <h3>glu__L_c</h3><p>C5H8NO4</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.01%</td>
#       <td>0.0005491</td>
#       <td>ADCS</td>
#       <td>chor_c + gln__L_c --&gt; 4adcho_c + glu__L_c</td>
#     </tr>
#     <tr>
#       <td>0.01%</td>
#       <td>0.0005491</td>
#       <td>ADCYRS</td>
#       <td>adcobdam_c + 4.0 atp_c + 4.0 gln__L_c + 4.0 h2o_c --&gt; adcobhex_c + 4.0 adp_c + 4.0 glu__L_c + 4.0 h_c + 4.0 pi_c</td>
#     </tr>
#     <tr>
#       <td>1.89%</td>
#       <td>0.09784</td>
#       <td>ASNS1</td>
#       <td>asp__L_c + atp_c + gln__L_c + h2o_c --&gt; amp_c + asn__L_c + glu__L_c + h_c + ppi_c</td>
#     </tr>
#     <tr>
#       <td>0.94%</td>
#       <td>0.04872</td>
#       <td>GF6PTA</td>
#       <td>f6p_c + gln__L_c --&gt; gam6p_c + glu__L_c</td>
#     </tr>
#     <tr>
#       <td>74.82%</td>
#       <td>3.877</td>
#       <td>GLUDxi</td>
#       <td>glu__L_c + h2o_c + nad_c &lt;=&gt; akg_c + h_c + nadh_c + nh4_c</td>
#     </tr>
#     <tr>
#       <td>8.22%</td>
#       <td>0.4262</td>
#       <td>GLUDy</td>
#       <td>glu__L_c + h2o_c + nadp_c &lt;=&gt; akg_c + h_c + nadph_c + nh4_c</td>
#     </tr>
#     <tr>
#       <td>4.93%</td>
#       <td>0.2554</td>
#       <td>GLUPRT</td>
#       <td>gln__L_c + h2o_c + prpp_c --&gt; glu__L_c + ppi_c + pram_c</td>
#     </tr>
#     <tr>
#       <td>2.75%</td>
#       <td>0.1424</td>
#       <td>GMPS2</td>
#       <td>atp_c + gln__L_c + h2o_c + xmp_c --&gt; amp_c + glu__L_c + gmp_c + 2.0 h_c + ppi_c</td>
#     </tr>
#     <tr>
#       <td>0.01%</td>
#       <td>0.0002746</td>
#       <td>HYGBDIAS</td>
#       <td>2.0 atp_c + 2.0 gln__L_c + h2o_c + hgbyr_c --&gt; 2.0 adp_c + 2.0 glu__L_c + 2.0 h_c + hgbam_c + ppi_c</td>
#     </tr>
#     <tr>
#       <td>1.50%</td>
#       <td>0.07775</td>
#       <td>IG3PS</td>
#       <td>gln__L_c + prlp_c --&gt; aicar_c + eig3p_c + glu__L_c + h_c</td>
#     </tr>
#     <tr>
#       <td>4.93%</td>
#       <td>0.2554</td>
#       <td>PRFGS</td>
#       <td>atp_c + fgam_c + gln__L_c + h2o_c --&gt; adp_c + fpram_c + glu__L_c + h_c + pi_c</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>4.61%</td>
#       <td>-0.2388</td>
#       <td>ACGS</td>
#       <td>accoa_c + glu__L_c --&gt; acglu_c + coa_c + h_c</td>
#     </tr>
#     <tr>
#       <td>4.61%</td>
#       <td>-0.2388</td>
#       <td>ACOTA</td>
#       <td>acorn_c + akg_c &lt;=&gt; acg5sa_c + glu__L_c</td>
#     </tr>
#     <tr>
#       <td>7.75%</td>
#       <td>-0.4016</td>
#       <td>ALATA_L</td>
#       <td>akg_c + ala__L_c &lt;=&gt; glu__L_c + pyr_c</td>
#     </tr>
#     <tr>
#       <td>2.27%</td>
#       <td>-0.1176</td>
#       <td>AROAT</td>
#       <td>glu__L_c + h_c + pphn_c &lt;=&gt; Largn_c + akg_c</td>
#     </tr>
#     <tr>
#       <td>25.97%</td>
#       <td>-1.346</td>
#       <td>ASPTA</td>
#       <td>akg_c + asp__L_c &lt;=&gt; glu__L_c + oaa_c</td>
#     </tr>
#     <tr>
#       <td>3.59%</td>
#       <td>-0.1858</td>
#       <td>BIOMASS_KT2440_WT3</td>
#       <td>0.000223 10fthf_c + 0.000223 2fe2s_c + 0.000223 4fe4s_c + 0.000223 5mthf_c + 0.000279 accoa_c + 0.000223 adocbl_c + 0.598267 ala__L_c + 0.000223 amet_c + 0.354251 arg__L_c + 0.158931 asn__L_c + 0.284685 asp__L_c + 46.918883 atp_c + 0.000223 bmocogdp_c + 0.000223 btamp_c + 0.004226 ca2_c + 0.000223 chor_c + 0.004226 cl_c + 1.8e-05 clpn140_p + 0.000578 clpn160_p + 0.002873 clpn161_p + 0.000192 clpn180_p + 0.001309 clpn181_p + 0.000167 coa_c + 0.002817 cobalt2_c + 0.00041 cpe160_c + 0.000226 cpg160_c + 0.159783 ctp_c + 0.002817 cu2_c + 0.055652 cys__L_c + 0.010804 datp_c + 0.01721 dctp_c + 0.017423 dgtp_c + 0.010854 dttp_c + 0.000223 fad_c + 0.00634 fe2_c + 0.00634 fe3_c + 0.251507 gln__L_c + 0.301809 glu__L_c + 0.431309 gly_c + 0.000223 gthrd_c + 0.210704 gtp_c + 41.397362 h2o_c + 0.000223 hemeO_c + 0.126289 his__L_c + 0.244551 ile__L_c + 0.158509 k_c + 0.628769 leu__L_c + 0.000223 lipopb_c + 0.008696 lpspput_e + 0.180336 lys__L_c + 3.1e-05 malcoa_c + 0.122008 met__L_c + 0.007044 mg2_c + 0.000223 mlthf_c + 0.002817 mn2_c + 0.002817 mobd_c + 0.000223 mocogdp_c + 0.001979 murein3p3p_p + 0.000326 murein3px4p_p + 0.007917 murein4p4p_p + 0.002941 murein4px4p_p + 6.6e-05 murein4px4px4p_p + 0.003522 na1_c + 0.001786 nad_c + 4.4e-05 nadh_c + 0.000111 nadp_c + 0.000335 nadph_c + 0.010567 nh4_c + 0.002817 ni2_c + 0.000251 pe140_c + 0.007882 pe160_c + 0.039155 pe161_c + 0.002622 pe180_c + 0.017845 pe181_c + 0.000138 pg140_c + 0.004354 pg160_c + 0.021632 pg161_c + 0.001449 pg180_c + 0.009859 pg181_c + 0.191038 phe__L_c + 0.000223 pheme_c + 0.000223 pqqh2_c + 0.26328 pro__L_c + 0.03327 ptrc_c + 0.000223 pydx5p_c + 0.000223 pyovd_kt_e + 0.000223 q8h2_c + 0.000223 ribflv_c + 0.301274 ser__L_c + 0.000223 sheme_c + 0.003522 so4_c + 9.8e-05 succoa_c + 0.000223 thf_c + 0.000223 thmnp_c + 0.000223 thmpp_c + 0.256324 thr__L_c + 0.077592 trp__L_c + 0.135921 tyr__L_c + 5.5e-05 udcpdp_c + 0.143215 utp_c + 0.389034 val__L_c + 0.002817 zn2_c --&gt; 46.7502 adp_c + 46.7502 h_c + 46.746677 pi_c + 0.73868 ppi_c</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>-0.0001373</td>
#       <td>DABAAT2</td>
#       <td>24dab_c + akg_c + h_c &lt;=&gt; aspsa_c + glu__L_c</td>
#     </tr>
#     <tr>
#       <td>0.01%</td>
#       <td>-0.0005491</td>
#       <td>DHFS</td>
#       <td>atp_c + dhpt_c + glu__L_c --&gt; adp_c + dhf_c + h_c + pi_c</td>
#     </tr>
#     <tr>
#       <td>19.95%</td>
#       <td>-1.034</td>
#       <td>GLNS_copy2</td>
#       <td>atp_c + glu__L_c + nh4_c --&gt; adp_c + gln__L_c + h_c + pi_c</td>
#     </tr>
#     <tr>
#       <td>3.13%</td>
#       <td>-0.1621</td>
#       <td>GLU5K</td>
#       <td>atp_c + glu__L_c --&gt; adp_c + glu5p_c</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>-0.0001373</td>
#       <td>GLUCYS_copy1</td>
#       <td>atp_c + cys__L_c + glu__L_c --&gt; adp_c + glucys_c + h_c + pi_c</td>
#     </tr>
#     <tr>
#       <td>0.32%</td>
#       <td>-0.01633</td>
#       <td>GLUR</td>
#       <td>glu__D_c &lt;=&gt; glu__L_c</td>
#     </tr>
#     <tr>
#       <td>0.08%</td>
#       <td>-0.004393</td>
#       <td>GLUTRS</td>
#       <td>atp_c + glu__L_c + trnaglu_c --&gt; amp_c + glutrna_c + ppi_c</td>
#     </tr>
#     <tr>
#       <td>1.50%</td>
#       <td>-0.07775</td>
#       <td>HSTPT</td>
#       <td>glu__L_c + imacp_c --&gt; akg_c + hisp_c</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>-0.0001373</td>
#       <td>OHPBAT</td>
#       <td>glu__L_c + ohpb_c &lt;=&gt; akg_c + phthr_c</td>
#     </tr>
#     <tr>
#       <td>22.14%</td>
#       <td>-1.147</td>
#       <td>PSERT</td>
#       <td>3php_c + glu__L_c --&gt; akg_c + pser__L_c</td>
#     </tr>
#     <tr>
#       <td>2.46%</td>
#       <td>-0.1273</td>
#       <td>SDPTA</td>
#       <td>akg_c + sl26da_c &lt;=&gt; glu__L_c + sl2a6o_c</td>
#     </tr>
#     <tr>
#       <td>1.62%</td>
#       <td>-0.08381</td>
#       <td>TYRTA</td>
#       <td>akg_c + tyr__L_c &lt;=&gt; 34hpp_c + glu__L_c</td>
#     </tr>
#   </tbody>
# </table>

# %%
# retrieve fluxes from producing and consuming reactions for the given metabolite

model.metabolites.asp__L_c.summary()
# Out:
# <h3>asp__L_c</h3><p>C4H6NO4</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100.00%</td>
#       <td>1.346</td>
#       <td>ASPTA</td>
#       <td>akg_c + asp__L_c &lt;=&gt; glu__L_c + oaa_c</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>14.17%</td>
#       <td>-0.1907</td>
#       <td>ADSS</td>
#       <td>asp__L_c + gtp_c + imp_c --&gt; dcamp_c + gdp_c + 2.0 h_c + pi_c</td>
#     </tr>
#     <tr>
#       <td>16.20%</td>
#       <td>-0.2181</td>
#       <td>ARGSS</td>
#       <td>asp__L_c + atp_c + citr__L_c --&gt; amp_c + argsuc_c + h_c + ppi_c</td>
#     </tr>
#     <tr>
#       <td>7.27%</td>
#       <td>-0.09784</td>
#       <td>ASNS1</td>
#       <td>asp__L_c + atp_c + gln__L_c + h2o_c --&gt; amp_c + asn__L_c + glu__L_c + h_c + ppi_c</td>
#     </tr>
#     <tr>
#       <td>0.01%</td>
#       <td>-0.0001373</td>
#       <td>ASP3H</td>
#       <td>akg_c + asp__L_c + o2_c --&gt; 3hasp__L_c + co2_c + succ_c</td>
#     </tr>
#     <tr>
#       <td>15.17%</td>
#       <td>-0.2042</td>
#       <td>ASPCT</td>
#       <td>asp__L_c + cbp_c --&gt; cbasp_c + h_c + pi_c</td>
#     </tr>
#     <tr>
#       <td>15.07%</td>
#       <td>-0.2029</td>
#       <td>ASPK</td>
#       <td>asp__L_c + atp_c &lt;=&gt; 4pasp_c + adp_c</td>
#     </tr>
#     <tr>
#       <td>0.10%</td>
#       <td>-0.001401</td>
#       <td>ASPO3</td>
#       <td>asp__L_c + q8_c --&gt; h_c + iasp_c + q8h2_c</td>
#     </tr>
#     <tr>
#       <td>13.02%</td>
#       <td>-0.1753</td>
#       <td>BIOMASS_KT2440_WT3</td>
#       <td>0.000223 10fthf_c + 0.000223 2fe2s_c + 0.000223 4fe4s_c + 0.000223 5mthf_c + 0.000279 accoa_c + 0.000223 adocbl_c + 0.598267 ala__L_c + 0.000223 amet_c + 0.354251 arg__L_c + 0.158931 asn__L_c + 0.284685 asp__L_c + 46.918883 atp_c + 0.000223 bmocogdp_c + 0.000223 btamp_c + 0.004226 ca2_c + 0.000223 chor_c + 0.004226 cl_c + 1.8e-05 clpn140_p + 0.000578 clpn160_p + 0.002873 clpn161_p + 0.000192 clpn180_p + 0.001309 clpn181_p + 0.000167 coa_c + 0.002817 cobalt2_c + 0.00041 cpe160_c + 0.000226 cpg160_c + 0.159783 ctp_c + 0.002817 cu2_c + 0.055652 cys__L_c + 0.010804 datp_c + 0.01721 dctp_c + 0.017423 dgtp_c + 0.010854 dttp_c + 0.000223 fad_c + 0.00634 fe2_c + 0.00634 fe3_c + 0.251507 gln__L_c + 0.301809 glu__L_c + 0.431309 gly_c + 0.000223 gthrd_c + 0.210704 gtp_c + 41.397362 h2o_c + 0.000223 hemeO_c + 0.126289 his__L_c + 0.244551 ile__L_c + 0.158509 k_c + 0.628769 leu__L_c + 0.000223 lipopb_c + 0.008696 lpspput_e + 0.180336 lys__L_c + 3.1e-05 malcoa_c + 0.122008 met__L_c + 0.007044 mg2_c + 0.000223 mlthf_c + 0.002817 mn2_c + 0.002817 mobd_c + 0.000223 mocogdp_c + 0.001979 murein3p3p_p + 0.000326 murein3px4p_p + 0.007917 murein4p4p_p + 0.002941 murein4px4p_p + 6.6e-05 murein4px4px4p_p + 0.003522 na1_c + 0.001786 nad_c + 4.4e-05 nadh_c + 0.000111 nadp_c + 0.000335 nadph_c + 0.010567 nh4_c + 0.002817 ni2_c + 0.000251 pe140_c + 0.007882 pe160_c + 0.039155 pe161_c + 0.002622 pe180_c + 0.017845 pe181_c + 0.000138 pg140_c + 0.004354 pg160_c + 0.021632 pg161_c + 0.001449 pg180_c + 0.009859 pg181_c + 0.191038 phe__L_c + 0.000223 pheme_c + 0.000223 pqqh2_c + 0.26328 pro__L_c + 0.03327 ptrc_c + 0.000223 pydx5p_c + 0.000223 pyovd_kt_e + 0.000223 q8h2_c + 0.000223 ribflv_c + 0.301274 ser__L_c + 0.000223 sheme_c + 0.003522 so4_c + 9.8e-05 succoa_c + 0.000223 thf_c + 0.000223 thmnp_c + 0.000223 thmpp_c + 0.256324 thr__L_c + 0.077592 trp__L_c + 0.135921 tyr__L_c + 5.5e-05 udcpdp_c + 0.143215 utp_c + 0.389034 val__L_c + 0.002817 zn2_c --&gt; 46.7502 adp_c + 46.7502 h_c + 46.746677 pi_c + 0.73868 ppi_c</td>
#     </tr>
#     <tr>
#       <td>0.01%</td>
#       <td>-0.0001373</td>
#       <td>FBACS</td>
#       <td>24dab_c + 3hasp__L_c + asp__L_c + gly_c + n5horn_c + orn_c + ser__L_c --&gt; fbac_kt_c + 6.0 h2o_c</td>
#     </tr>
#     <tr>
#       <td>18.97%</td>
#       <td>-0.2553</td>
#       <td>PRASCSi_copy2</td>
#       <td>5aizc_c + asp__L_c + atp_c --&gt; 25aics_c + adp_c + h_c + pi_c</td>
#     </tr>
#   </tbody>
# </table>

# %%
# retrieve fluxes from producing and consuming reactions for the given metabolite

model.metabolites.leu__L_c.summary()
# Out:
# <h3>leu__L_c</h3><p>C6H13NO2</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100.00%</td>
#       <td>0.3871</td>
#       <td>LLEUDr</td>
#       <td>h2o_c + leu__L_c + nad_c &lt;=&gt; 4mop_c + h_c + nadh_c + nh4_c</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100.00%</td>
#       <td>-0.3871</td>
#       <td>BIOMASS_KT2440_WT3</td>
#       <td>0.000223 10fthf_c + 0.000223 2fe2s_c + 0.000223 4fe4s_c + 0.000223 5mthf_c + 0.000279 accoa_c + 0.000223 adocbl_c + 0.598267 ala__L_c + 0.000223 amet_c + 0.354251 arg__L_c + 0.158931 asn__L_c + 0.284685 asp__L_c + 46.918883 atp_c + 0.000223 bmocogdp_c + 0.000223 btamp_c + 0.004226 ca2_c + 0.000223 chor_c + 0.004226 cl_c + 1.8e-05 clpn140_p + 0.000578 clpn160_p + 0.002873 clpn161_p + 0.000192 clpn180_p + 0.001309 clpn181_p + 0.000167 coa_c + 0.002817 cobalt2_c + 0.00041 cpe160_c + 0.000226 cpg160_c + 0.159783 ctp_c + 0.002817 cu2_c + 0.055652 cys__L_c + 0.010804 datp_c + 0.01721 dctp_c + 0.017423 dgtp_c + 0.010854 dttp_c + 0.000223 fad_c + 0.00634 fe2_c + 0.00634 fe3_c + 0.251507 gln__L_c + 0.301809 glu__L_c + 0.431309 gly_c + 0.000223 gthrd_c + 0.210704 gtp_c + 41.397362 h2o_c + 0.000223 hemeO_c + 0.126289 his__L_c + 0.244551 ile__L_c + 0.158509 k_c + 0.628769 leu__L_c + 0.000223 lipopb_c + 0.008696 lpspput_e + 0.180336 lys__L_c + 3.1e-05 malcoa_c + 0.122008 met__L_c + 0.007044 mg2_c + 0.000223 mlthf_c + 0.002817 mn2_c + 0.002817 mobd_c + 0.000223 mocogdp_c + 0.001979 murein3p3p_p + 0.000326 murein3px4p_p + 0.007917 murein4p4p_p + 0.002941 murein4px4p_p + 6.6e-05 murein4px4px4p_p + 0.003522 na1_c + 0.001786 nad_c + 4.4e-05 nadh_c + 0.000111 nadp_c + 0.000335 nadph_c + 0.010567 nh4_c + 0.002817 ni2_c + 0.000251 pe140_c + 0.007882 pe160_c + 0.039155 pe161_c + 0.002622 pe180_c + 0.017845 pe181_c + 0.000138 pg140_c + 0.004354 pg160_c + 0.021632 pg161_c + 0.001449 pg180_c + 0.009859 pg181_c + 0.191038 phe__L_c + 0.000223 pheme_c + 0.000223 pqqh2_c + 0.26328 pro__L_c + 0.03327 ptrc_c + 0.000223 pydx5p_c + 0.000223 pyovd_kt_e + 0.000223 q8h2_c + 0.000223 ribflv_c + 0.301274 ser__L_c + 0.000223 sheme_c + 0.003522 so4_c + 9.8e-05 succoa_c + 0.000223 thf_c + 0.000223 thmnp_c + 0.000223 thmpp_c + 0.256324 thr__L_c + 0.077592 trp__L_c + 0.135921 tyr__L_c + 5.5e-05 udcpdp_c + 0.143215 utp_c + 0.389034 val__L_c + 0.002817 zn2_c --&gt; 46.7502 adp_c + 46.7502 h_c + 46.746677 pi_c + 0.73868 ppi_c</td>
#     </tr>
#   </tbody>
# </table>

# %%
# retrieve fluxes from producing and consuming reactions for the given metabolite

model.metabolites.acald_c.summary()
# Out:
# <h3>acald_c</h3><p>C2H4O</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100.00%</td>
#       <td>0.3085</td>
#       <td>ACALD</td>
#       <td>acald_c + coa_c + nad_c &lt;=&gt; accoa_c + h_c + nadh_c</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>99.96%</td>
#       <td>-0.3084</td>
#       <td>THRA</td>
#       <td>thr__L_c &lt;=&gt; acald_c + gly_c</td>
#     </tr>
#     <tr>
#       <td>0.04%</td>
#       <td>-0.0001373</td>
#       <td>THRA2</td>
#       <td>athr__L_c &lt;=&gt; acald_c + gly_c</td>
#     </tr>
#   </tbody>
# </table>

# %%
# retrieve fluxes from producing and consuming reactions for the given metabolite

model.metabolites.get_by_id("3pg_c").summary()
# Out:
# <h3>3pg_c</h3><p>C3H4O7P</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100.00%</td>
#       <td>5.318</td>
#       <td>PGK</td>
#       <td>3pg_c + atp_c &lt;=&gt; 13dpg_c + adp_c</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>21.58%</td>
#       <td>-1.147</td>
#       <td>PGCD</td>
#       <td>3pg_c + nad_c --&gt; 3php_c + h_c + nadh_c</td>
#     </tr>
#     <tr>
#       <td>78.42%</td>
#       <td>-4.17</td>
#       <td>PGM</td>
#       <td>2pg_c &lt;=&gt; 3pg_c</td>
#     </tr>
#   </tbody>
# </table>

# %%
# retrieve fluxes from producing and consuming reactions for the given metabolite

model.metabolites.get_by_id("2ddg6p_c").summary()
# Out:
# <h3>2ddg6p_c</h3><p>C6H8O9P</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100.00%</td>
#       <td>5.45</td>
#       <td>EDD</td>
#       <td>6pgc_c --&gt; 2ddg6p_c + h2o_c</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100.00%</td>
#       <td>-5.45</td>
#       <td>EDA</td>
#       <td>2ddg6p_c --&gt; g3p_c + pyr_c</td>
#     </tr>
#   </tbody>
# </table>

# %%
# retrieve fluxes from producing and consuming reactions for the given metabolite

model.metabolites.get_by_id("6pgc_c").summary()
# Out:
# <h3>6pgc_c</h3><p>C6H10O10P</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100.00%</td>
#       <td>6.3</td>
#       <td>GNK</td>
#       <td>atp_c + glcn_c --&gt; 6pgc_c + adp_c + h_c</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>86.51%</td>
#       <td>-5.45</td>
#       <td>EDD</td>
#       <td>6pgc_c --&gt; 2ddg6p_c + h2o_c</td>
#     </tr>
#     <tr>
#       <td>13.49%</td>
#       <td>-0.8498</td>
#       <td>GND</td>
#       <td>6pgc_c + nadp_c --&gt; co2_c + nadph_c + ru5p__D_c</td>
#     </tr>
#   </tbody>
# </table>

# %%
# retrieve fluxes from producing and consuming reactions for the given metabolite

model.metabolites.glcn_p.summary()
# Out:
# <h3>glcn_p</h3><p>C6H11O7</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100.00%</td>
#       <td>6.3</td>
#       <td>GLCDpp</td>
#       <td>glc__D_p + h2o_p + q8_c --&gt; glcn_p + h_p + q8h2_c</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100.00%</td>
#       <td>-6.3</td>
#       <td>GLCNt2rpp</td>
#       <td>glcn_p + h_p &lt;=&gt; glcn_c + h_c</td>
#     </tr>
#   </tbody>
# </table>
